# %% [markdown]
# <a href="https://colab.research.google.com/github/Ifhamsb/Ifhamsb/blob/main/Exercise_NHANES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('NHANES.csv')

data.head(10)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
# 5  83737     2.0     2.0     NaN       2         2        72         1
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 7  83742     1.0     NaN     1.0       2         2        32         1
# 8  83743     NaN     NaN     NaN       2         1        18         5
# 9  83744     1.0     NaN     NaN       2         1        56         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# ...

# %%
data.shape
# Out:
# (5735, 28)

# %%
data.describe(include="all")
# Out:
#                SEQN       ALQ101       ALQ110       ALQ130       SMQ020  \
# count   5735.000000  5208.000000  1731.000000  3379.000000  5735.000000
# mean   88678.583435     1.336406     1.587522     3.911512     1.607149
# std     2882.139237     0.505514     0.623940    34.341839     0.571975
# min    83732.000000     1.000000     1.000000     1.000000     1.000000
# 25%    86164.000000     1.000000     1.000000     1.000000     1.000000
# 50%    88668.000000     1.000000     2.000000     2.000000     2.000000
# 75%    91178.500000     2.000000     2.000000     3.000000     2.000000
# max    93702.000000     9.000000     9.000000   999.000000     9.000000
#
#           RIAGENDR     RIDAGEYR     RIDRETH1     DMDCITZN     DMDEDUC2  \
# count  5735.000000  5735.000000  5735.000000  5734.000000  5474.000000
# mean      1.518919    48.052310     3.042371     1.185385     3.441725
# std       0.499686    18.431011     1.296793     0.491678     1.309700
# ...

# %%
pd.set_option('display.max_columns', None)

data.head(20)
# Out:
#      SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0   83732     1.0     NaN     1.0       1         1        62         3
# 1   83733     1.0     NaN     6.0       1         1        53         3
# 2   83734     1.0     NaN     NaN       1         1        78         3
# 3   83735     2.0     1.0     1.0       2         2        56         3
# 4   83736     2.0     1.0     1.0       2         2        42         4
# 5   83737     2.0     2.0     NaN       2         2        72         1
# 6   83741     1.0     NaN     8.0       1         1        22         4
# 7   83742     1.0     NaN     1.0       2         2        32         1
# 8   83743     NaN     NaN     NaN       2         1        18         5
# 9   83744     1.0     NaN     NaN       2         1        56         4
# 10  83747     1.0     NaN     1.0       1         1        46         3
# 11  83750     1.0     NaN     3.0       1         1        45         5
# ...

# %%
data.isnull()
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     False   False    True   False   False     False     False     False
# 1     False   False    True   False   False     False     False     False
# 2     False   False    True    True   False     False     False     False
# 3     False   False   False   False   False     False     False     False
# 4     False   False   False   False   False     False     False     False
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  False   False   False    True   False     False     False     False
# 5731  False   False   False    True   False     False     False     False
# 5732  False   False    True   False   False     False     False     False
# 5733  False    True    True    True   False     False     False     False
# 5734  False   False    True   False   False     False     False     False
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# ...

# %%
data.isnull().sum()
# Out:
# SEQN           0
# ALQ101       527
# ALQ110      4004
# ALQ130      2356
# SMQ020         0
# RIAGENDR       0
# RIDAGEYR       0
# RIDRETH1       0
# DMDCITZN       1
# DMDEDUC2     261
# DMDMARTL     261
# DMDHHSIZ       0
# WTINT2YR       0
# SDMVPSU        0
# SDMVSTRA       0
# INDFMPIR     601
# BPXSY1       334
# BPXDI1       334
# BPXSY2       200
# BPXDI2       200
# BMXWT         69
# BMXHT         62
# BMXBMI        73
# BMXLEG       390
# BMXARML      308
# BMXARMC      308
# BMXWAIST     367
# HIQ210      1003
# dtype: int64

# %%
import numpy as np

mean_ALQ101 = data['ALQ101'].mean()
mean_ALQ110 = data['ALQ110'].mean()
mean_ALQ130 = data['ALQ130'].mean()
mean_DMDCITZN = data['DMDCITZN'].mean()
mean_DMDEDUC2 = data['DMDEDUC2'].mean()
mean_DMDMARTL = data['DMDMARTL'].mean()
mean_INDFMPIR = data['INDFMPIR'].mean()
mean_BPXSY1 = data['BPXSY1'].mean()
mean_BPXDI1 = data['BPXDI1'].mean()
mean_BPXSY2 = data['BPXSY2'].mean()
mean_BPXDI2 = data['BPXDI2'].mean()
mean_BMXWT = data['BMXWT'].mean()
mean_BMXHT = data['BMXHT'].mean()
mean_BMXBMI = data['BMXBMI'].mean()
mean_BMXLEG = data['BMXLEG'].mean()
mean_BMXARML = data['BMXARML'].mean()
mean_BMXARMC = data['BMXARMC'].mean()
mean_BMXWAIST = data['BMXWAIST'].mean()
mean_HIQ210 = data['HIQ210'].mean()



print(round((mean_ALQ101), 1))
print(round((mean_ALQ110), 1))
print(round((mean_ALQ130), 1))
print(round((mean_DMDCITZN), 1))
print(round((mean_DMDEDUC2), 1))
print(round((mean_DMDMARTL), 1))
print(round((mean_INDFMPIR), 2))
print(round((mean_BPXSY1), 1))
print(round((mean_BPXDI1), 1))
print(round((mean_BPXSY2), 1))
print(round((mean_BPXDI2), 1))
print(round((mean_BMXWT), 1))
print(round((mean_BMXHT), 1))
print(round((mean_BMXBMI), 1))
print(round((mean_BMXLEG), 1))
print(round((mean_BMXARML), 1))
print(round((mean_BMXARMC), 1))
print(round((mean_BMXWAIST), 1))
print(round((mean_HIQ210), 1))
# Out:
# 1.3
# 1.6
# 3.9
# 1.2
# 3.4
# 2.6
# 2.4
# 125.1
# 69.5
# 124.8
# 69.3
# 81.3
# 166.1
# 29.4
# 38.6
# 37.1
# 33.1
# 99.6
# 1.9
